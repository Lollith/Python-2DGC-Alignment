# %%
import ipywidgets as widgets
from IPython.display import display, Markdown
import os

# Dossier contenant les notebooks
notebooks = {
    "Peak Detection": "notebooks/peak_detection.ipynb",
    # "NIST Identification": "notebooks/2_nist_identification.ipynb",
    # "Alignement des pics": "notebooks/3_consensus_alignement.ipynb",
    # "Comparaison R/Python": "notebooks/4_compare_R_python.ipynb",
    # "Export CSV": "notebooks/5_export_csv.ipynb"
}

def create_dashboard(notebooks_dict):
    items = []
    for title, path in notebooks_dict.items():
        button = widgets.Button(description=title, layout=widgets.Layout(width="50%"))
        def on_click(p=path):
            def click_callback(b):
                display(Markdown(f"🔗 [Ouvrir {title}](./{p})"))
            return click_callback
        button.on_click(on_click())
        items.append(button)
    return widgets.VBox(items)

dashboard = create_dashboard(notebooks)
display(Markdown("# 🧭 Tableau de bord - GCxGC-MS"))
display(dashboard)
