# %%
import ipywidgets as widgets
from IPython.display import display, HTML, Markdown
import os
from datetime import datetime

# Configuration des notebooks
notebooks = {
    "Peak Detection": {
        "path": "run_peak_detection.ipynb",
        "description": "Détection des pics chromatographiques",
        "icon": "🔍",
        "status": "active"
    },
    "NIST Identification": {
        "path": "2_nist_identification.ipynb", 
        "description": "Identification des composés via base NIST",
        "icon": "🔬",
        "status": "coming_soon"
    },
    "Alignement des pics": {
        "path": "run_peak_alignment.ipynb",
        "description": "Alignement et consensus des pics détectés",
        "icon": "📊",
        "status": "active"
    },
    "Filtrage des résultats d'alignement": {
        "path": "run_peak_filtering.ipynb",
        "description": "Filtrage des résultats d'alignement",
        "icon": "🔍",
        "status": "coming_soon"
    },
    "Analyses Statistiques": {
        "path": "4_compare_R_python.ipynb",
        "description": "Analyse statistique des données chromatographiques",
        "icon": "⚖️",
        "status": "coming_soon"
    },
    "Export CSV": {
        "path": "notebooks/5_export_csv.ipynb",
        "description": "Export des résultats en format CSV",
        "icon": "📤",
        "status": "coming_soon"
    }
}

def create_dashboard(notebooks_dict):
    """Créer un tableau de bord moderne avec des cartes stylisées"""
    
    # Style CSS pour les cartes
    card_style = """
    <style>
    .dashboard-container {
        max-width: 1200px;
        margin: 0 auto;
        font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
    }
    
    .dashboard-header {
        text-align: center;
        background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
        color: white;
        padding: 30px;
        border-radius: 15px;
        margin-bottom: 30px;
        box-shadow: 0 8px 32px rgba(0,0,0,0.1);
    }
    
    .dashboard-header h1 {
        margin: 0;
        font-size: 2.5em;
        font-weight: 300;
    }
    
    .dashboard-header p {
        margin: 10px 0 0 0;
        opacity: 0.9;
        font-size: 1.1em;
    }
    
    .cards-grid {
        display: grid;
        grid-template-columns: repeat(auto-fit, minmax(350px, 1fr));
        gap: 20px;
        margin-top: 20px;
    }
    
    .card {
        background: white;
        border-radius: 12px;
        padding: 25px;
        box-shadow: 0 4px 20px rgba(0,0,0,0.08);
        border: 1px solid #e1e5e9;
        transition: all 0.3s ease;
        position: relative;
        overflow: hidden;
    }
    
    .card:hover {
        transform: translateY(-5px);
        box-shadow: 0 8px 30px rgba(0,0,0,0.12);
    }
    
    .card.active::before {
        content: '';
        position: absolute;
        top: 0;
        left: 0;
        right: 0;
        height: 4px;
        background: linear-gradient(90deg, #4CAF50, #45a049);
    }
    
    .card.coming-soon::before {
        content: '';
        position: absolute;
        top: 0;
        left: 0;
        right: 0;
        height: 4px;
        background: linear-gradient(90deg, #ff9800, #f57c00);
    }
    
    .card-header {
        display: flex;
        align-items: center;
        margin-bottom: 15px;
    }
    
    .card-icon {
        font-size: 2.5em;
        margin-right: 15px;
    }
    
    .card-title {
        font-size: 1.4em;
        font-weight: 600;
        color: #2c3e50;
        margin: 0;
    }
    
    .card-description {
        color: #7f8c8d;
        margin-bottom: 20px;
        line-height: 1.5;
    }
    
    .card-footer {
        display: flex;
        justify-content: space-between;
        align-items: center;
    }
    
    .status-badge {
        padding: 4px 12px;
        border-radius: 20px;
        font-size: 0.8em;
        font-weight: 600;
        text-transform: uppercase;
    }
    
    .status-active {
        background: #e8f5e8;
        color: #4CAF50;
    }
    
    .status-coming-soon {
        background: #fff3e0;
        color: #ff9800;
    }
    
    .open-link {
        color: #667eea;
        text-decoration: none;
        font-weight: 600;
        padding: 8px 16px;
        border-radius: 6px;
        border: 2px solid #667eea;
        transition: all 0.3s ease;
    }
    
    .open-link:hover {
        background: #667eea;
        color: white;
    }
    
    .stats-section {
        background: #f8f9fa;
        border-radius: 12px;
        padding: 20px;
        margin: 30px 0;
        text-align: center;
    }
    
    .stats-grid {
        display: grid;
        grid-template-columns: repeat(auto-fit, minmax(150px, 1fr));
        gap: 20px;
        margin-top: 15px;
    }
    
    .stat-item {
        background: white;
        padding: 15px;
        border-radius: 8px;
        box-shadow: 0 2px 8px rgba(0,0,0,0.05);
    }
    
    .stat-number {
        font-size: 2em;
        font-weight: bold;
        color: #667eea;
    }
    
    .stat-label {
        color: #7f8c8d;
        font-size: 0.9em;
        margin-top: 5px;
    }
    </style>
    """
    
    
    # Générer le HTML du tableau de bord
    html_content = f"""
    {card_style}
    <div class="dashboard-container">
        <div class="dashboard-header">
            <h1>🧭 Tableau de bord GCxGC-MS</h1>
            <p><center>Analyse chromatographique bidimensionnelle - Spectrométrie de masse</center></p>
        
        <div class="cards-grid">
    """
    
    # Générer les cartes pour chaque notebook
    for title, info in notebooks_dict.items():
        status_class = f"status-{info['status'].replace('_', '-')}"
        status_text = "Disponible" if info['status'] == 'active' else "Bientôt disponible"
        
        card_html = f"""
        <div class="card {info['status']}">
            <div class="card-header">
                <div class="card-icon">{info['icon']}</div>
                <div>
                    <h3 class="card-title">{title}</h3>
                </div>
            </div>
            <div class="card-description">
                {info['description']}
            </div>
            <div class="card-footer">
                <span class="status-badge {status_class}">{status_text}</span>
        """
        
        if info['status'] == 'active':
            card_html += f'<a href="./{info["path"]}" class="open-link">Ouvrir →</a>'
        else:
            card_html += '<span style="color: #bdc3c7;">Bientôt...</span>'
            
        card_html += """
            </div>
        </div>
        """
        
        html_content += card_html
    
    html_content += """
        </div>
    </div>
    """
    
    return HTML(html_content)

def create_navigation_buttons(notebooks_dict):
    """Créer des boutons de navigation traditionnels en complément"""
    buttons = []
    
    for title, info in notebooks_dict.items():
        if info['status'] == 'active':
            # Bouton stylisé pour les notebooks actifs
            button = widgets.Button(
                description=f"{info['icon']} {title}",
                button_style='primary',
                layout=widgets.Layout(
                    width='300px',
                    height='45px',
                    margin='5px'
                ),
                style={'font_weight': 'bold'}
            )
            
            def create_callback(path, name):
                def on_click(b):
                    display(Markdown(f"🔗 **[Ouvrir {name}](./{path})**"))
                return on_click
            
            button.on_click(create_callback(info['path'], title))
            buttons.append(button)
        else:
            # Bouton désactivé pour les notebooks à venir
            button = widgets.Button(
                description=f"{info['icon']} {title} (bientôt)",
                button_style='',
                disabled=True,
                layout=widgets.Layout(
                    width='300px',
                    height='45px',
                    margin='5px'
                ),
                style={'font_weight': 'normal'}
            )
            buttons.append(button)
    
    return widgets.VBox(
        buttons,
        layout=widgets.Layout(
            align_items='center',
            margin='20px 0'
        )
    )

# Créer et afficher le tableau de bord
def display_dashboard():
    """Afficher le tableau de bord complet"""
    
    # Tableau de bord principal (moderne)
    dashboard_html = create_dashboard(notebooks)
    display(dashboard_html)
    
    # # Section alternative avec boutons (optionnelle)
    # display(Markdown("---"))
    # display(Markdown("## 🎛️ Navigation alternative"))
    # navigation_buttons = create_navigation_buttons(notebooks)
    # display(navigation_buttons)
    
    # Footer avec informations
    footer_html = HTML("""
    <div style="text-align: center; margin-top: 40px; padding: 20px; 
                background: #f8f9fa; border-radius: 10px; color: #6c757d;">
        <p><strong>GCxGC-MS Dashboard</strong> - Version 1.0</p>
        <p>Développé pour l'analyse chromatographique bidimensionnelle</p>
        <p><em>Dernière mise à jour: """ + datetime.now().strftime('%d/%m/%Y à %H:%M') + """</em></p>
    </div>
    """)
    display(footer_html)

# Exécuter le tableau de bord
display_dashboard()
# Out:
#
#     <style>
#     .dashboard-container {
#         max-width: 1200px;
#         margin: 0 auto;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#     }
#
#     .dashboard-header {
#         text-align: center;
#         background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#         color: white;
#         padding: 30px;
#         border-radius: 15px;
#         margin-bottom: 30px;
#         box-shadow: 0 8px 32px rgba(0,0,0,0.1);
#     }
#
#     .dashboard-header h1 {
#         margin: 0;
#         font-size: 2.5em;
#         font-weight: 300;
#     }
#
#     .dashboard-header p {
#         margin: 10px 0 0 0;
#         opacity: 0.9;
#         font-size: 1.1em;
#     }
#
#     .cards-grid {
#         display: grid;
#         grid-template-columns: repeat(auto-fit, minmax(350px, 1fr));
#         gap: 20px;
#         margin-top: 20px;
#     }
#
#     .card {
#         background: white;
#         border-radius: 12px;
#         padding: 25px;
# ...

# %%
# import ipywidgets as widgets
# from IPython.display import display, HTML, Markdown
# import os
# from datetime import datetime

# # Configuration des notebooks - Adaptée pour Voilà
# notebooks = {
#     "Peak Detection": {
#         "path": "run_peak_detection.ipynb",
#         "description": "Détection des pics chromatographiques",
#         "icon": "🔍",
#         "status": "active",
#         "voila_url": "run_peak_detection.ipynb"
#     },
#     "NIST Identification": {
#         "path": "2_nist_identification.ipynb", 
#         "description": "Identification des composés via base NIST",
#         "icon": "🔬",
#         "status": "coming_soon",
#         "voila_url": "2_nist_identification.ipynb"
#     },
#     "Alignement des pics": {
#         "path": "3_consensus_alignement.ipynb",
#         "description": "Alignement et consensus des pics détectés",
#         "icon": "📊",
#         "status": "coming_soon",
#         "voila_url": "3_consensus_alignement.ipynb"
#     },
#     "Analyses Statistiques": {
#         "path": "4_compare_R_python.ipynb",
#         "description": "Analyse statistique des données chromatographiques",
#         "icon": "⚖️",
#         "status": "coming_soon",
#         "voila_url": "4_compare_R_python.ipynb"
#     },
#     "Export CSV": {
#         "path": "5_export_csv.ipynb",
#         "description": "Export des résultats en format CSV",
#         "icon": "📤",
#         "status": "coming_soon",
#         "voila_url": "5_export_csv.ipynb"
#     }
# }

# def create_voila_dashboard(notebooks_dict):
#     """Créer un tableau de bord optimisé pour Voilà"""
    
#     # Style CSS adapté pour Voilà
#     card_style = """
#     <style>
#     .dashboard-container {
#         max-width: 1200px;
#         margin: 0 auto;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#         padding: 20px;
#     }
    
#     .dashboard-header {
#         text-align: center;
#         background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#         color: white;
#         padding: 30px;
#         border-radius: 15px;
#         margin-bottom: 30px;
#         box-shadow: 0 8px 32px rgba(0,0,0,0.1);
#     }
    
#     .dashboard-header h1 {
#         margin: 0;
#         font-size: 2.5em;
#         font-weight: 300;
#     }
    
#     .dashboard-header p {
#         margin: 10px 0 0 0;
#         opacity: 0.9;
#         font-size: 1.1em;
#     }
    
#     .cards-grid {
#         display: grid;
#         grid-template-columns: repeat(auto-fit, minmax(350px, 1fr));
#         gap: 20px;
#         margin-top: 20px;
#     }
    
#     .card {
#         background: white;
#         border-radius: 12px;
#         padding: 25px;
#         box-shadow: 0 4px 20px rgba(0,0,0,0.08);
#         border: 1px solid #e1e5e9;
#         transition: all 0.3s ease;
#         position: relative;
#         overflow: hidden;
#     }
    
#     .card:hover {
#         transform: translateY(-5px);
#         box-shadow: 0 8px 30px rgba(0,0,0,0.12);
#     }
    
#     .card.active::before {
#         content: '';
#         position: absolute;
#         top: 0;
#         left: 0;
#         right: 0;
#         height: 4px;
#         background: linear-gradient(90deg, #4CAF50, #45a049);
#     }
    
#     .card.coming-soon::before {
#         content: '';
#         position: absolute;
#         top: 0;
#         left: 0;
#         right: 0;
#         height: 4px;
#         background: linear-gradient(90deg, #ff9800, #f57c00);
#     }
    
#     .card-header {
#         display: flex;
#         align-items: center;
#         margin-bottom: 15px;
#     }
    
#     .card-icon {
#         font-size: 2.5em;
#         margin-right: 15px;
#     }
    
#     .card-title {
#         font-size: 1.4em;
#         font-weight: 600;
#         color: #2c3e50;
#         margin: 0;
#     }
    
#     .card-description {
#         color: #7f8c8d;
#         margin-bottom: 20px;
#         line-height: 1.5;
#     }
    
#     .card-footer {
#         display: flex;
#         justify-content: space-between;
#         align-items: center;
#     }
    
#     .status-badge {
#         padding: 4px 12px;
#         border-radius: 20px;
#         font-size: 0.8em;
#         font-weight: 600;
#         text-transform: uppercase;
#     }
    
#     .status-active {
#         background: #e8f5e8;
#         color: #4CAF50;
#     }
    
#     .status-coming-soon {
#         background: #fff3e0;
#         color: #ff9800;
#     }
    
#     .open-link {
#         color: #667eea;
#         text-decoration: none;
#         font-weight: 600;
#         padding: 8px 16px;
#         border-radius: 6px;
#         border: 2px solid #667eea;
#         transition: all 0.3s ease;
#         display: inline-block;
#     }
    
#     .open-link:hover {
#         background: #667eea;
#         color: white;
#     }
    
#     .open-link.disabled {
#         color: #bdc3c7;
#         border-color: #bdc3c7;
#         cursor: not-allowed;
#     }
    
#     .footer-info {
#         text-align: center;
#         margin-top: 40px;
#         padding: 20px;
#         background: #f8f9fa;
#         border-radius: 10px;
#         color: #6c757d;
#     }
    
#     .instructions {
#         background: #e3f2fd;
#         border: 1px solid #2196f3;
#         border-radius: 8px;
#         padding: 15px;
#         margin: 20px 0;
#     }
    
#     .instructions h3 {
#         color: #1976d2;
#         margin-top: 0;
#     }
#     </style>
#     """
    
#     # Générer le HTML du tableau de bord
#     html_content = f"""
#     {card_style}
#     <div class="dashboard-container">
#         <div class="dashboard-header">
#             <h1>🧭 Tableau de bord GCxGC-MS</h1>
#             <p>Analyse chromatographique bidimensionnelle - Spectrométrie de masse</p>
#         </div>
        
#         <div class="instructions">
#             <h3>📋 Instructions d'utilisation</h3>
#             <p><strong>Pour Voilà :</strong> Cliquez sur les liens "Ouvrir dans Voilà" pour accéder aux notebooks interactifs.</p>
#             <p><strong>URL correcte :</strong> http://localhost:8866/nom_du_notebook.ipynb</p>
#             <p><strong>⚠️ Attention :</strong> N'utilisez PAS /voila/render/ dans l'URL - Voilà l'ajoute automatiquement</p>
#         </div>
        
#         <div class="cards-grid">
#     """
    
#     # Générer les cartes pour chaque notebook
#     for title, info in notebooks_dict.items():
#         status_class = f"status-{info['status'].replace('_', '-')}"
#         status_text = "Disponible" if info['status'] == 'active' else "Bientôt disponible"
        
#         card_html = f"""
#         <div class="card {info['status']}">
#             <div class="card-header">
#                 <div class="card-icon">{info['icon']}</div>
#                 <div>
#                     <h3 class="card-title">{title}</h3>
#                 </div>
#             </div>
#             <div class="card-description">
#                 {info['description']}
#             </div>
#             <div class="card-footer">
#                 <span class="status-badge {status_class}">{status_text}</span>
#         """
        
#         if info['status'] == 'active':
#             card_html += f'''
#                 <a href="{info["voila_url"]}" target="_blank" class="open-link">
#                     Ouvrir dans Voilà →
#                 </a>
#             '''
#         else:
#             card_html += '<span class="open-link disabled">Bientôt...</span>'
            
#         card_html += """
#             </div>
#         </div>
#         """
        
#         html_content += card_html
    
#     html_content += f"""
#         </div>
        
#         <div class="footer-info">
#             <p><strong>GCxGC-MS Dashboard</strong> - Version 1.0 (Voilà)</p>
#             <p>Développé pour l'analyse chromatographique bidimensionnelle</p>
#             <p><em>Dernière mise à jour: {datetime.now().strftime('%d/%m/%Y à %H:%M')}</em></p>
#         </div>
#     </div>
#     """
    
#     return HTML(html_content)

# def create_voila_navigation_widgets(notebooks_dict):
#     """Créer des widgets de navigation interactifs pour Voilà"""
    
#     # Widget de sélection
#     notebook_options = []
#     for title, info in notebooks_dict.items():
#         if info['status'] == 'active':
#             notebook_options.append((f"{info['icon']} {title}", info['voila_url']))
    
#     if notebook_options:
#         dropdown = widgets.Dropdown(
#             options=[('Sélectionner un notebook...', '')] + notebook_options,
#             description='Navigation:',
#             style={'description_width': 'initial'},
#             layout=widgets.Layout(width='400px')
#         )
        
#         output_widget = widgets.Output()
        
#         def on_dropdown_change(change):
#             with output_widget:
#                 output_widget.clear_output()
#                 if change['new']:
#                     display(HTML(f'''
#                         <div style="margin-top: 10px; padding: 10px; background: #e8f5e8; 
#                                     border-radius: 5px; border-left: 4px solid #4CAF50;">
#                             <p><strong>Lien Voilà :</strong></p>
#                             <p><a href="{change['new']}" target="_blank" 
#                                  style="color: #4CAF50; font-weight: bold; text-decoration: none;">
#                                 {change['new']} →
#                             </a></p>
#                             <p><small>Cliquez sur le lien pour ouvrir dans un nouvel onglet</small></p>
#                         </div>
#                     '''))
        
#         dropdown.observe(on_dropdown_change, names='value')
        
#         return widgets.VBox([
#             widgets.HTML('<h3>🎛️ Navigation rapide</h3>'),
#             dropdown,
#             output_widget
#         ])
    
#     return widgets.HTML('<p>Aucun notebook actif disponible.</p>')

# # Fonction principale pour afficher le dashboard Voilà
# def display_voila_dashboard():
#     """Afficher le tableau de bord optimisé pour Voilà"""
    
#     # Tableau de bord principal
#     dashboard_html = create_voila_dashboard(notebooks)
#     display(dashboard_html)
    
#     # Widget de navigation interactif
#     display(Markdown("---"))
#     navigation_widget = create_voila_navigation_widgets(notebooks)
#     display(navigation_widget)
    
 

# # Exécuter le tableau de bord pour Voilà
# display_voila_dashboard()
# Out:
#
#     <style>
#     .dashboard-container {
#         max-width: 1200px;
#         margin: 0 auto;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#         padding: 20px;
#     }
#
#     .dashboard-header {
#         text-align: center;
#         background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#         color: white;
#         padding: 30px;
#         border-radius: 15px;
#         margin-bottom: 30px;
#         box-shadow: 0 8px 32px rgba(0,0,0,0.1);
#     }
#
#     .dashboard-header h1 {
#         margin: 0;
#         font-size: 2.5em;
#         font-weight: 300;
#     }
#
#     .dashboard-header p {
#         margin: 10px 0 0 0;
#         opacity: 0.9;
#         font-size: 1.1em;
#     }
#
#     .cards-grid {
#         display: grid;
#         grid-template-columns: repeat(auto-fit, minmax(350px, 1fr));
#         gap: 20px;
#         margin-top: 20px;
#     }
#
#     .card {
#         background: white;
#         border-radius: 12px;
# ...
